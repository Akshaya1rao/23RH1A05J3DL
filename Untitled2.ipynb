# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt

# %%
(x_train,y_train),(x_test,y_test)=mnist.load_data()

# %%
x_train=x_train/255.0
x_test=x_test/255.0

# %%
model=Sequential(Flatten(input_shape=(28,28)),
                Dense(64,activation='relu'),
                Dense(1,activation='sigmoid'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-8-1420202686.py in <cell line: 0>()
# ----> 1 model=Sequential(Flatten(input_shape=(28,28)),
#       2                 Dense(64,activation='relu'),
#       3                 Dense(1,activation='sigmoid'))
#
# /usr/local/lib/python3.11/dist-packages/keras/src/models/sequential.py in __init__(self, layers, trainable, name)
#      68
#      69     def __init__(self, layers=None, trainable=True, name=None):
# ---> 70         super().__init__(trainable=trainable, name=name)
#      71         self._functional = None
# ...

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-9-4293868659.py in <cell line: 0>()
# ----> 1 model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
#
# NameError: name 'model' is not defined

# %%
model.fit(x_train,y_train,epchos=10,validation_data=(x_test,y_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-10-2925470858.py in <cell line: 0>()
# ----> 1 model.fit(x_train,y_train,epchos=10,validation_data=(x_test,y_test))
#
# NameError: name 'model' is not defined

# %%
index=7
sample=x_test[index]
pred=model.predict(sample.reshape(1,28,28),verbose=0)
pred_val=int(pred[0][0]>=0.5)
print(f"Actual digit: {y_test[index]}")
print(f"predicted:{pred[0][0]}")

# %%
plt.imshow(sample,cmap='gray')
plt.title("predict 4")
plt.show()
